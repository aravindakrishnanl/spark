# %%
"Siva Siva"
# Out:
# 'Siva Siva'

# %%
import pandas as pd
from neuralprophet import NeuralProphet, set_log_level
set_log_level("ERROR")
# Out:
# c:\Users\aravi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning_fabric\__init__.py:29: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__("pkg_resources").declare_namespace(__name__)
# Importing plotly failed. Interactive plots will not work.
# Importing plotly failed. Interactive plots will not work.

# %%
df = pd.read_csv("walmart.csv", parse_dates=["date"])
df = df.rename(
    columns={
        "date": "ds",         
        "item_sold": "y",   
    }
)

# df.sort_values(["product_id", "ds"], inplace=True)
# df["ds"] = df["ds"].dt.floor("D")           
# bool_cols = ["promotion_flag", "new_arrival", "holiday_flag"]
# df[bool_cols] = df[bool_cols].astype(int)

# id_col = "product_id"

# %%
m = NeuralProphet(
    # n_lags=14,          # look-back window (2 weeks)
    # n_forecasts=7,      # forecast horizon (1 week)
    # yearly_seasonality=True,
    # weekly_seasonality=True,
    # daily_seasonality=False,
    # learning_rate=0.01,
)

# lagged = ["price", "total_product_available",
#           "promotion_flag", "new_arrival",
#           "day_of_week", "month", "holiday_flag"]

# for col in lagged:
#     m.add_lagged_regressor(col)             
# m.id_col = id_col

# %%
plt = df.plot(x="ds", y="y", figsize=(15, 5))
